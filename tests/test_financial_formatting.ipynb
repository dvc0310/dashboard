# %%
from testutil import change_to_root

change_to_root()
# Out:
# Current working directory: /Users/David/Desktop/NORS_Outages_Completed/tests
# Changed to project root directory: /Users/David/Desktop/NORS_Outages_Completed

# %%
import pandas as pd

excel = pd.read_excel('datasets/SPGlobal_Wireless.xlsx', header=None, engine='openpyxl')
excel
# Out:
#                                               0             1    \
# 0                                             NaN           NaN
# 1                                             NaN           NaN
# 2                                             NaN           NaN
# 3                                             NaN           NaN
# 4                                  SP_ENTITY_NAME  SP_ENTITY_ID
# 5                                             NaN           NaN
# 6                                             NaN           NaN
# 7                  Allegiance Communications, LLC       4151207
# 8                              AT&T Inc. (NYSE:T)       4024242
# 9    Charter Communications, Inc. (NASDAQGS:CHTR)       4121481
# 10           Comcast Corporation (NASDAQGS:CMCSA)       4057180
# 11                       Cox Communications, Inc.       4024830
# 12                Garden Valley Telephone Company       4165831
# 13                              GCI Liberty, Inc.       4057188
# ...

# %%
csv_file = pd.read_csv('datasets/SPGlobal_Wireless.csv')
csv_file
# Out:
#                                            #NAME?    Unnamed: 1  \
# 0                                          #NAME?        #NAME?
# 1                                  SP_ENTITY_NAME  SP_ENTITY_ID
# 2                                             NaN           NaN
# 3                                             NaN           NaN
# 4                  Allegiance Communications, LLC       4151207
# 5                              AT&T Inc. (NYSE:T)       4024242
# 6    Charter Communications, Inc. (NASDAQGS:CHTR)       4121481
# 7            Comcast Corporation (NASDAQGS:CMCSA)       4057180
# 8                        Cox Communications, Inc.       4024830
# 9                 Garden Valley Telephone Company       4165831
# 10                              GCI Liberty, Inc.       4057188
# 11           Lumen Technologies, Inc. (NYSE:LUMN)       4057179
# 12                             Sprint Corporation       6411697
# 13    Telephone and Data Systems, Inc. (NYSE:TDS)       4057224
# ...
